# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd

# %%
wd = webdriver.Chrome()

# %%
wd.get('https://www.coffeebeankorea.com/store/store.asp')

# %%
wd.execute_script("storePop2('407')")

# %%
html = wd.page_source
soup = BeautifulSoup(html, 'html.parser')
store_name = soup.select('div.store_txt > h2')
print(store_name[0].text)
# Out:
# 마곡케이스퀘어점

# %%
store_info = soup.select('div.store_txt > table.store_table > tbody > tr > td')
print(store_info)
# Out:
# [<td>월~금 8:00 ~ 18:00 | 주말,공휴일 9:00 - 19:00</td>, <td>1만원 구매시 1시간무료주차가능/건물합산 불가 <br/></td>, <td>서울특별시 강서구 마곡중앙로 105-7 (케이스퀘어) 마곡 TOWER 1, 1층 D-101호  <!--span class="lot">(서울특별시 강서구 마곡중앙로 105-7 (케이스퀘어) 마곡 TOWER 1, 1층 D-101호)</span--></td>, <td>02-3662-9805</td>, <td class="hallcake">홀케익 당일 수령가능</td>]

# %%
print(store_info[2].text)
# Out:
# 서울특별시 강서구 마곡중앙로 105-7 (케이스퀘어) 마곡 TOWER 1, 1층 D-101호
